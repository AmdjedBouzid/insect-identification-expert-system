# %% [markdown]
# <img src='data:image/png;base64,...'/>

# %%
knowledge_base = {
    "facts": [
        "colorful wings",
        "feeds on nectar",
        "active during the day",
        "dull-colored wings",
        "active at night",
        "attracted to light",
        "yellow",
        "black stripes",
        "buzzing sound",
        "thin waist",
        "small size",
        "lives in colonies",
        "carries food",
        "eats wood",
        "red shell with black spots",
        "long legs",
        "jumps high",
        "chirping sound",
        "long transparent wings",
        "large compound eyes",
        "thin body",
        "bites humans",
        "oval body",
        "fast-moving",
        "eight legs",
        "web-building behavior",
        "emits light",
        "camouflaged body",
        "slow movement",
        "hard shell",
        "feeds on plants or scavenger",
        "long forelegs",
        "triangular head",
        "number of bites > 5",
        "wingspan > 1.5 cm",
        "colony size > 50"
    ],
    # , ->and
    
"rules": [
    {"result": "Butterfly", "condition": [{"predicate": "colored wings", "positive": True}, {"predicate": "feeds on nectar", "positive": True}]},
    {"result": "Butterfly", "condition": [{"predicate": "colored wings", "positive": True}, {"predicate": "active during the day", "positive": True}]},

    {"result": "Moth", "condition": [{"predicate": "dull-colored wings", "positive": True}, {"predicate": "active at night", "positive": True}]},
    {"result": "Moth", "condition": [{"predicate": "dull-colored wings", "positive": True}, {"predicate": "attracted to light", "positive": True}]},

    {"result": "Bee", "condition": [{"predicate": "yellow", "positive": True}, {"predicate": "black stripes", "positive": True}, {"predicate": "buzzing sound", "positive": True}]},
    {"result": "Bee", "condition": [{"predicate": "yellow", "positive": True}, {"predicate": "black stripes", "positive": True}, {"predicate": "feeds on nectar", "positive": True}]},

    {"result": "Wasp", "condition": [{"predicate": "yellow", "positive": True}, {"predicate": "black stripes", "positive": True}, {"predicate": "buzzing sound", "positive": True}, {"predicate": "thin waist", "positive": True}]},
    {"result": "Wasp", "condition": [{"predicate": "yellow", "positive": True}, {"predicate": "black stripes", "positive": True}, {"predicate": "feeds on nectar", "positive": True}, {"predicate": "thin waist", "positive": True}]},

    {"result": "Ant", "condition": [{"predicate": "small size", "positive": True}, {"predicate": "lives in colonies", "positive": True}]},
    {"result": "Ant", "condition": [{"predicate": "small size", "positive": True}, {"predicate": "carries food", "positive": True}]},

    {"result": "Termite", "condition": [{"predicate": "small size", "positive": True}, {"predicate": "lives in colonies", "positive": True}, {"predicate": "eats wood", "positive": True}]},
    {"result": "Termite", "condition": [{"predicate": "small size", "positive": True}, {"predicate": "carries food", "positive": True}, {"predicate": "eats wood", "positive": True}]},

    {"result": "Ladybug", "condition": [{"predicate": "small size", "positive": True}, {"predicate": "red shell with black spots", "positive": True}]},

    {"result": "Grasshopper", "condition": [{"predicate": "long legs", "positive": True}, {"predicate": "jumps high", "positive": True}]},
    {"result": "Grasshopper", "condition": [{"predicate": "long legs", "positive": True}, {"predicate": "chirping sound", "positive": True}]},

    {"result": "Dragonfly", "condition": [{"predicate": "long transparent wings", "positive": True}, {"predicate": "large compound eyes", "positive": True}]},

    {"result": "Mosquito", "condition": [{"predicate": "thin body", "positive": True}, {"predicate": "buzzing sound", "positive": True}]},
    {"result": "Mosquito", "condition": [{"predicate": "thin body", "positive": True}, {"predicate": "bites humans", "positive": True}]},

    {"result": "Cockroach", "condition": [{"predicate": "oval body", "positive": True}, {"predicate": "fast-moving", "positive": True}]},
    {"result": "Cockroach", "condition": [{"predicate": "oval body", "positive": True}, {"predicate": "active at night", "positive": True}]},

    {"result": "Spider", "condition": [{"predicate": "eight legs", "positive": True}, {"predicate": "web-building behavior", "positive": True}]},

    {"result": "Firefly", "condition": [{"predicate": "dull-colored wings", "positive": True}, {"predicate": "active at night", "positive": True}, {"predicate": "emits light", "positive": True}]},
    {"result": "Firefly", "condition": [{"predicate": "dull-colored wings", "positive": True}, {"predicate": "attracted to light", "positive": True}, {"predicate": "emits light", "positive": True}]},

    {"result": "Stick Insect", "condition": [{"predicate": "camouflaged body", "positive": True}, {"predicate": "slow movement", "positive": True}]},

    {"result": "Beetle", "condition": [{"predicate": "hard shell", "positive": True}, {"predicate": "feeds on plants", "positive": True}]},
    {"result": "Beetle", "condition": [{"predicate": "hard shell", "positive": True}, {"predicate": "scavenger", "positive": True}]},

    {"result": "Praying Mantis", "condition": [{"predicate": "long forelegs", "positive": True}, {"predicate": "triangular head", "positive": True}]},

    {"result": "Ant Colony Leader", "condition": [{"predicate": "small size", "positive": True}, {"predicate": "lives in colonies", "positive": True}, {"predicate": "colony size > 50", "positive": True}]},
    {"result": "Ant Colony Leader", "condition": [{"predicate": "small size", "positive": True}, {"predicate": "carries food", "positive": True}, {"predicate": "colony size > 50" ,"positive" : True}]},

    {"result": "Queen Bee", "condition": [{"predicate": "yellow", "positive": True}, {"predicate": "black stripes", "positive": True}, {"predicate": "buzzing sound", "positive": True}, {"predicate": "wingspan > 1.5", "positive": True}]},
    {"result": "Queen Bee", "condition": [{"predicate": "yellow", "positive": True}, {"predicate": "black stripes", "positive": True}, {"predicate": "feeds on nectar", "positive": True}, {"predicate": "wingspan > 1.5", "positive": True}]},

    {"result": "Mosquito Carrier", "condition": [{"predicate": "thin body", "positive": True}, {"predicate": "buzzing sound", "positive": True}, {"predicate": "number of bites > 5", "positive": True}]},
    {"result": "Mosquito Carrier", "condition": [{"predicate": "thin body", "positive": True}, {"predicate": "bites humans", "positive": True}, {"predicate": "number of bites > 5", "positive": True}]},

    {"result": "Housefly", "condition": [{"predicate": "small size", "positive": True}, {"predicate": "buzzing sound", "positive": True}, {"predicate": "yellow", "positive": False}]},
    {"result": "Housefly", "condition": [{"predicate": "small size", "positive": True}, {"predicate": "buzzing sound", "positive": True}, {"predicate": "black trips", "positive": False}]},
    {"result": "Housefly", "condition": [{"predicate": "small size", "positive": True}, {"predicate": "buzzing sound", "positive": True}, {"predicate": "active at night ", "positive": False}]},
    {"result": "Housefly", "condition": [{"predicate": "small size", "positive": True}, {"predicate": "buzzing sound", "positive": True}, {"predicate": "attracted to light", "positive": False}]},
    
]


}

# %%
def forward_chaining(Facts,Conclusion):
    if Conclusion in Facts :
        return True
    
def Is_Satisfied(Conditions,Facts):
    if len(Conditions)==0 : 
        return True

# %%
        # {"result": "Ant Colony Leader", "condition": ["small size", "lives in colonies","colony size > 50"]},
        # {"result": "Ant Colony Leader", "condition": ["small size", "carries food","colony size > 50"]},

        
        # {"result": "Queen Bee", "condition": ["yellow", "black stripes", "buzzing sound","wingspan > 1.5 cm"]},
        # {"result": "Queen Bee", "condition": ["yellow", "black stripes", "feeds on nectar","wingspan > 1.5 cm"]},

        # {"result": "Mosquito Carrier", "condition": ["thin body", "buzzing sound","number of bites > 5"]},
        # {"result": "Mosquito Carrier", "condition": ["thin body", "bites humans","number of bites > 5"]},
